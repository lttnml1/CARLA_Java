# %%
import shapely.geometry as sg
from shapely.affinity import rotate
import matplotlib.pyplot as plt

# %%
car1 = sg.Polygon([(1,2),(1,3),(3,3),(3,2)])
car2 = sg.Polygon([(1,1),(1,1.8),(3,1.8),(3,1)])

# %%
ego = sg.Polygon([(-96.23345884667069, 1.368047832077906), (-91.26082208232789, 1.2416035647278818), (-91.31263795508713, -0.7961441264809821), (-96.28527471942994, -0.669699859130958), (-96.23345884667069, 1.368047832077906)])
adv = sg.Polygon([(-96.2473768122436, -4.028915515724776), (-100.23500016210684, -4.0511045111209825), (-100.2452989690064, -2.200287827666628), (-96.25767561914316, -2.178098832270422), (-96.2473768122436, -4.028915515724776)])

# %%
#car1 = rotate(car1,90)
combined = [ego, adv]
fig, axs = plt.subplots()
axs.set_aspect('equal','datalim')
for geom in combined:
    xs, ys = geom.exterior.xy
    #make sure to swap the plot of x's and y's due to CARLA's coordinate system
    axs.fill(ys,xs,alpha=0.5,fc='r',ec='none')
plt.show()

# %%
car1.intersects(car2)
car1.distance(car2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3216\1197711776.py in <module>
# ----> 1 car1.intersects(car2)
#       2 car1.distance(car2)
#
# NameError: name 'car1' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

V = np.array([[0.9996694326400757, -0.025419605895876884],[-4.473289,-3.400553]])
origin = np.array([[0,0],[0,0]]) # origin point

plt.quiver(*origin, V[:,1], V[:,0], color=['b','r'], scale=5)
plt.show()

# %%
import math
def unit_vector(vector):
    return vector/np.linalg.norm(vector)
def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    angle =  math.degrees(math.atan2(v1_u[0],v1_u[1]) - math.atan2(v2_u[0],v2_u[1]))
    if(angle < 0 and abs(angle) > 180): angle +=360
    if(angle > 180): angle =angle-360
    return angle
    return np.arccos(np.dot(v1_u,v2_u))
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
angle_between(V[0],V[1])
# Out:
# -141.30163442585084
