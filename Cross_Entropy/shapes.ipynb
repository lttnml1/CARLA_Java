# %%
import shapely.geometry as sg
from shapely.affinity import rotate
import matplotlib.pyplot as plt

# %%
car1 = sg.Polygon([(1,2),(1,3),(3,3),(3,2)])
car2 = sg.Polygon([(1,1),(1,1.8),(3,1.8),(3,1)])

# %%
car1 = sg.Polygon([(-84.46387247482721, 11.40346199957353), (-85.5725024560362, 16.252589201450903), (-83.58536763747749, 16.70689719232101), (-82.4767376562685, 11.857769990443636), (-84.46387247482721, 11.40346199957353)])
car2 = sg.Polygon([(-87.37601828306056, 13.18892067707167), (-87.20300360200703, 17.172850797288326), (-85.35390115053318, 17.092547714346786), (-85.5269158315867, 13.108617594130136), (-87.37601828306056, 13.18892067707167)])

# %%
#car1 = rotate(car1,90)
combined = [car1,car2]
fig, axs = plt.subplots()
axs.set_aspect('equal','datalim')
for geom in combined:
    xs, ys = geom.exterior.xy
    #make sure to swap the plot of x's and y's due to CARLA's coordinate system
    axs.fill(ys,xs,alpha=0.5,fc='r',ec='none')
plt.show()

# %%
car1.intersects(car2)
# Out:
# True

# %%
import numpy as np
import matplotlib.pyplot as plt

V = np.array([[-0.22287188470363617, 0.9748374223709106],[-2.340340,1.085554]])
origin = np.array([[0,0],[0,0]]) # origin point

plt.quiver(*origin, V[:,1], V[:,0], color=['b','r'], scale=5)
plt.show()

# %%
import math
def unit_vector(vector):
    return vector/np.linalg.norm(vector)
def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return math.atan2(v2_u[0],v2_u[1]) - math.atan2(v1_u[0],v1_u[1])
    #return np.arccos(np.dot(v1_u,v2_u))
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
import math
math.degrees(angle_between(V[0],V[1]))
# Out:
# -52.238127545207476
