# %%
import shapely.geometry as sg
from shapely.affinity import rotate
import matplotlib.pyplot as plt

# %%
car1 = sg.Polygon([(1,2),(1,3),(3,3),(3,2)])
car2 = sg.Polygon([(1,1),(1,1.8),(3,1.8),(3,1)])

# %%
car1 = sg.Polygon([(-99.87465607607945, 1.3680635387138977), (-94.91117204252305, 1.6950662779532024), (-94.77716887509243, -0.3389306956963196), (-99.74065290864883, -0.6659334349356243), (-99.87465607607945, 1.3680635387138977)])
car2 = sg.Polygon([(-89.24046899311308, 0.7259090407577788), (-89.22426792893857, 4.713561214331962), (-87.37343786723848, 4.7060416476043425), (-87.38963893141299, 0.7183894740301604), (-89.24046899311308, 0.7259090407577788)])

# %%
#car1 = rotate(car1,90)
combined = [car1,car2]
fig, axs = plt.subplots()
axs.set_aspect('equal','datalim')
for geom in combined:
    xs, ys = geom.exterior.xy
    #make sure to swap the plot of x's and y's due to CARLA's coordinate system
    axs.fill(ys,xs,alpha=0.5,fc='r',ec='none')
plt.show()

# %%
car1.intersects(car2)
car1.distance(car2)
# Out:
# 5.594724809391005

# %%
import numpy as np
import matplotlib.pyplot as plt

V = np.array([[0.9978324770927429, 0.06573889404535294],[9.018959, 2.201409]])
origin = np.array([[0,0],[0,0]]) # origin point

plt.quiver(*origin, V[:,1], V[:,0], color=['b','r'], scale=5)
plt.show()

# %%
import math
def unit_vector(vector):
    return vector/np.linalg.norm(vector)
def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return math.atan2(v1_u[0],v1_u[1]) - math.atan2(v2_u[0],v2_u[1])
    #return np.arccos(np.dot(v1_u,v2_u))
    return np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0))

# %%
import math
math.degrees(angle_between(V[0],V[1]))
# Out:
# 9.947635632430847
